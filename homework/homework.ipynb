# %% [markdown]
# ## Question 1.

# %%
# !uv --version
# Out:
# uv 0.6.5 (bcbcd0a1e 2025-03-06)

# %% [markdown]
# ## Question 2.

# %% [markdown]
# sha256:b4fc2525eca2c69a59260f583c56a7557c6ccdf8deafdba6e060f94c1c59738e.

# %% [markdown]
# ## Question 3.

# %%
import pickle

# %%
with open('pipeline_v1.bin', 'rb') as f:
    pipeline = pickle.load(f)

# %%
datapoint = {
    "lead_source": "paid_ads",
    "number_of_courses_viewed": 2,
    "annual_income": 79276.0
}

# %%
pipeline.predict_proba(datapoint)
# Out:
# array([[0.46639273, 0.53360727]])

# %% [markdown]
# 0.53360727.

# %% [markdown]
# ## Question 4.

# %% [markdown]
# Script for serving the model, predict.py.

# %% [markdown]
# 0.5340417283801275.

# %% [markdown]
# ## Question 5.

# %% [markdown]
# 121 MB.

# %% [markdown]
# ## Question 6.

# %% [markdown]
# 0.59.
